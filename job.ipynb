# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-8745fd2c-a3d4-4f92-b596-059de5fe2ce6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8745fd2c-a3d4-4f92-b596-059de5fe2ce6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Job.csv to Job.csv

# %%
import io
dataset = pd.read_csv(io.BytesIO(uploaded['Job.csv']))
dataset.head(10)
# Out:
#    Annual Income(In lakhs)  Work Experience
# 0                        5                2
# 1                        7                5
# 2                        3                1
# 3                        5                2
# 4                       10                5

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)
y_pred = regressor.predict(X_train)

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Annual Income(In lakhs) vs Experience(Training set)')
plt.xlabel('Experience')
plt.ylabel('Annual Income(In lakhs)')
plt.show()
